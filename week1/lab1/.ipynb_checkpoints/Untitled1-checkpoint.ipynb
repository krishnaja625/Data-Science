# %%
import seaborn as sns
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

import numpy as np
from numpy import linalg as LA
from numpy import arange
import pandas as pd

import sklearn
from sklearn.datasets.mldata import fetch_mldata
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA

# %%
iris = pd.read_csv("Iris.csv")

# %%
print((iris['Species']).unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
print(iris.groupby('Species').size())
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
fig = plt.figure(figsize = (27,20))
iris.hist()
plt.suptitle("Histogram", fontsize=16)
plt.show()

# %%
iris.hist(by='Species', figsize =(12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1aeaa438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b40e588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1b433b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b4eb0b8>]],
#       dtype=object)

# %%
sns.lmplot(x="PetalLengthCm", y = "PetalWidthCm", data = iris, hue = "Species", fit_reg = "False", legend ="False")

# %%
sns.lmplot(x="PetalLengthCm", y = "SepalWidthCm", data = iris, hue = "Species", fit_reg = "False", legend ="False")

# %%
sns.lmplot(x="SepalLengthCm", y = "PetalWidthCm", data = iris, hue = "Species", fit_reg = "False", legend ="False")

# %%
sns.lmplot(x="PetalWidthCm", y = "SepalLengthCm", data = iris, hue = "Species", fit_reg = "False", legend ="False")

# %%
sns.lmplot(x="SepalLengthCm", y = "SepalWidthCm", data = iris, hue = "Species", fit_reg = "False", legend ="False")

# %%
from sklearn,decomposition import PCA
